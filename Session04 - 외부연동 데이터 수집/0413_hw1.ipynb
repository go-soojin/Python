# %%
# 라이브러리 선언
import pandas as pd
from bs4 import BeautifulSoup 
import requests # 웹페이지 접속 요청

# %%
# 타겟 URL 선언 및 접속
targetUrl = "https://www.timeanddate.com/holidays/south-korea"
resp = requests.get(url=targetUrl)
resp.encoding = "utf-8"
html = resp.text
htmlObj = BeautifulSoup(html, "html.parser")
htmlObj
# Out:
# <!DOCTYPE html>
# <!--
# scripts and programs that download content transparent to the user are not allowed without permission
# --><html lang="en"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><title>Holidays and observances in South Korea in 2021</title><meta content="Overview of holidays and many observances in South Korea during the year 2021" name="description"/><meta content="https://www.timeanddate.com/scripts/cityog.php?title=Holidays%20%26%20Observations&amp;tint=0xB53E38&amp;country=2021&amp;state=South%20Korea&amp;image=seoul1" property="og:image"/><meta content="website" property="og:type"/><style>
# @font-face{font-family:iconfont;src:url("/common/fonts/iconfont.woff2?v7") format("woff2"),url("/common/fonts/iconfont.woff?v7") format("woff"),url("/common/fonts/iconfont.ttf?v7") format("truetype"),url("/common/fonts/iconfont.svg?v7#iconfont") format("svg");font-weight:400;font-style:normal}
# </style>
# ...

# %%
tableTag=htmlObj.find(name ="table", attrs = {"id":"holidays-table"} )

# %%
DateList = []
WeekList = []
NameList = []
TypeList = []

# %%
for j in range(0,len(AllDate)):
    ### date 가져오기
    AllDate = tableTag.findAll(name ="th", attrs = {"class":"nw"} )
    EachDate = AllDate[j].text
    DateList.append(EachDate)
    
    for k in range(0,len(AllWeek)):
        ### weekinfo 가져오기
        AllWeek = tableTag.findAll(name ="td", attrs = {"class":"nw"} )
        EachWeek = AllWeek[k].text
        WeekList.append(EachWeek)
        
        for l in range(0,len(AllName)):
            ### holiday_name 가져오기
            AllName = tableTag.findAll(name ="a")
            EachName = AllName[l].text
            NameList.append(EachName)
            
            for i in range(2,len(Allweek), +3):
                Allweek = tableTag.findAll(name ="td")
                Type = Allweek[i].text
                TypeList.append(Type)

# %%
df = pd.DataFrame(zip(DateList, WeekList, NameList, TypeList))

# %%
columnTitle = ["date", "weekinfo", "holiday_name", "type"]

# %%
df.columns = columnTitle

# %%
df
# Out:
#        date weekinfo               holiday_name              type
# 0     1월 1일      금요일             New Year's Day    Public Holiday
# 1    2월 11일      목요일            Seollal Holiday    Public Holiday
# 2    2월 12일      금요일                    Seollal    Public Holiday
# 3    2월 13일      토요일            Seollal Holiday    Public Holiday
# 4    2월 14일      일요일            Valentine's Day        Observance
# 5     3월 1일      월요일  Independence Movement Day  National holiday
# 6    3월 20일      토요일              March Equinox            Season
# 7     4월 5일      월요일                  Arbor Day        Observance
# 8     5월 1일      토요일                  Labor Day      Bank Holiday
# 9     5월 5일      수요일             Children's Day    Public Holiday
# 10    5월 8일      토요일               Parents' Day        Observance
# 11   5월 15일      토요일              Teacher's Day        Observance
# 12   5월 19일      수요일          Buddha's Birthday    Public Holiday
# ...

# %%
TypeList=[]
NameList = []
WeekList = []

# %%
for i in range(0, len(Allweek), +3):
    Week = Allweek[i].text
    WeekList.append(Week)
    Name = Allweek[i+1].text
    NameList.append(Name)
    Type = Allweek[i+2].text
    TypeList.append(Type)

# %%
pd.DataFrame(zip(WeekList, NameList,TypeList))
# Out:
#       0                          1                 2
# 0   금요일             New Year's Day    Public Holiday
# 1   목요일            Seollal Holiday    Public Holiday
# 2   금요일                    Seollal    Public Holiday
# 3   토요일            Seollal Holiday    Public Holiday
# 4   일요일            Valentine's Day        Observance
# 5   월요일  Independence Movement Day  National holiday
# 6   토요일              March Equinox            Season
# 7   월요일                  Arbor Day        Observance
# 8   토요일                  Labor Day      Bank Holiday
# 9   수요일             Children's Day    Public Holiday
# 10  토요일               Parents' Day        Observance
# 11  토요일              Teacher's Day        Observance
# 12  수요일          Buddha's Birthday    Public Holiday
# 13  일요일               Memorial Day    Public Holiday
# 14  월요일              June Solstice            Season
# 15  토요일           Constitution Day        Observance
# 16  일요일             Liberation Day  National holiday
# ...
