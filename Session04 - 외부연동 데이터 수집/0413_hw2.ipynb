# %%
# 라이브러리 선언
import pandas as pd
from bs4 import BeautifulSoup 
import requests # 웹페이지 접속 요청

# %%
targetUrl = "https://www.loewe.com/int/en/women/bags"
resp = requests.get(url=targetUrl)
resp.encoding="utf-8"

html=resp.text

htmlObj = BeautifulSoup(html, "html.parser") 
htmlObj
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]> <html class="ie6 oldie" lang="en"> <![endif]-->
# <!--[if IE 7]> <html class="ie7 oldie" lang="en"> <![endif]-->
# <!--[if IE 8]> <html class="ie8 oldie" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <!--[if IE]<meta http-equiv="x-ua-compatible" content="ie=edge,chrome=1"><![endif]-->
# <meta content="width=device-width, initial-scale=1.0, viewport-fit=cover" name="viewport">
# <meta content="
# Shop the latest collections of luxury bags on the official LOEWE online store. Discover distinctive design, handcrafted by artisans." name="description"/>
# <meta content="" name="keywords"/>
# <link href="/on/demandware.static/Sites-LOE_INT-Site/-/en_CA/v1618356330700/css/fonts.css" rel="stylesheet"/>
# <link href="/on/demandware.static/Sites-LOE_INT-Site/-/en_CA/v1618356330700/css/main.css" rel="stylesheet"/>
# ...

# %%
TotalPage = htmlObj.find(name = "div", attrs={"id":"capds-js-product-grid"})

# %%
TotalPage
# Out:
# <div class="row no-gutters capds-productsearchresult--grid" id="capds-js-product-grid">
# <div class="capds-js-plp-grid capds-productsearchresult--4tile-grid capds-product-grid-element capds-js-gtmproductlistitem" data-colors-to-show="" data-position="1" data-product='{"brand":"Loewe","category":"women / w_bags / w_puzzle","id":"0010553493","name":"Small Puzzle bag in classic calfskin","price":3700000,"productColor":"Ochre Green/Soft White","productEan":"8432902919388","productGender":"Female","productMasterId":"A510S21X55","productStock":"In stock","variant":"Small","position":"1"}' id="capds-product-index-0">
# <!-- CQuotient Activity Tracking (viewCategory-cquotient.js) -->
# <script type="text/javascript">//<!--
# /* <![CDATA[ */
# (function(){
# try {
#     if(window.CQuotient) {
# 	var cq_params = {};
#
# 	cq_params.cookieId = window.CQuotient.getCQCookieId();
# 	cq_params.userId = window.CQuotient.getCQUserId();
# 	cq_params.emailId = CQuotient.getCQHashedEmail();
# ...

# %%
columnList =[]
rowList=[]

# %%
for i in range(0,len(Name)):

    ## 상품명
    Allname = TotalPage.findAll(name="p", attrs={"class":"capds-body-small-medium"})
    eachName = Allname[i].text
    Name = eachName.replace("\n","")
    Name

    ## 가격
    Allprice = TotalPage.findAll(name="span", attrs={"class":"capds-producttile__price--sales"})
    eachPrice = Allprice[i].text
    Price = eachPrice.replace("\n","")
    Price

    columnList.append(Name)
    columnList.append(Price)
    rowList.append(columnList)

    columnList

    columnList = []

# %%
columnList = ["상품명", "가격"]

# %%
result = pd.DataFrame(rowList)

# %%
result.columns = columnList

# %%
result
# Out:
#                                                   상품명              가격
# 0                Small Puzzle bag in classic calfskin  ₩ 3,700,000.00
# 1             Small Puzzle Edge bag in nappa calfskin  ₩ 3,900,000.00
# 2                Small Puzzle bag in classic calfskin  ₩ 3,700,000.00
# 3           Small Puzzle bag in soft grained calfskin  ₩ 3,600,000.00
# 4                 Mini Puzzle bag in classic calfskin  ₩ 2,700,000.00
# 5                 Mini Puzzle bag in classic calfskin  ₩ 2,600,000.00
# 6                 Mini Puzzle bag in classic calfskin  ₩ 2,700,000.00
# 7                 Mini Puzzle bag in classic calfskin  ₩ 2,600,000.00
# 8   Small Surplus Leather Woven basket bag in calf...  ₩ 3,100,000.00
# 9   Small Surplus Leather Woven basket bag in calf...  ₩ 3,100,000.00
# 10  Small Surplus Leather Woven basket bag in calf...  ₩ 3,100,000.00
# 11                  Flamenco clutch in nappa calfskin  ₩ 2,900,000.00
# ...
